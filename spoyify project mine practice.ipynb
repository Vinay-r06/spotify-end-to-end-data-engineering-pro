# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.25.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting redis>=3.5.3 (from spotipy)
#   Downloading redis-5.2.1-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: requests>=2.25.0 in c:\users\kiran\appdata\local\programs\python\python312\lib\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\kiran\appdata\local\programs\python\python312\lib\site-packages (from spotipy) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kiran\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.25.0->spotipy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kiran\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kiran\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.25.0->spotipy) (2024.8.30)
# Downloading spotipy-2.25.0-py3-none-any.whl (30 kB)
# Downloading redis-5.2.1-py3-none-any.whl (261 kB)
# Installing collected packages: redis, spotipy
# Successfully installed redis-5.2.1 spotipy-2.25.0

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

client_credentials_manager = SpotifyClientCredentials(client_id="5d7e59ab50654df5a4aeac7d4864a157",client_secret="3ea7699c9b6a4f8da8bfa1716f5c5aa3")
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/2WqL87lDvGdC7twAITNkwF"

# %%
playlist_link.split("/")
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '2WqL87lDvGdC7twAITNkwF']

# %%
playlist_uri = playlist_link.split("/")[-1]

# %%
playlist_uri
# Out:
# '2WqL87lDvGdC7twAITNkwF'

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/2WqL87lDvGdC7twAITNkwF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2025-02-26T08:27:44Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31n3wir7uk5es22uv5dcseinv23i'},
#     'href': 'https://api.spotify.com/v1/users/31n3wir7uk5es22uv5dcseinv23i',
#     'id': '31n3wir7uk5es22uv5dcseinv23i',
#     'type': 'user',
#     'uri': 'spotify:user:31n3wir7uk5es22uv5dcseinv23i'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/45GzIiGfnR8atWLnqnjR96',
#      'id': '45GzIiGfnR8atWLnqnjR96',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273db317d407e81fcfaf7dfcd60',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02db317d407e81fcfaf7dfcd60',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851db317d407e81fcfaf7dfcd60',
#        'width': 64}],
#      'name': 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)',
#      'release_date': '2024-11-06',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:45GzIiGfnR8atWLnqnjR96',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'},
#        'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ',
#        'id': '5VVN3xZw1i2qihfITZlvCZ',
#        'name': 'G. V. Prakash',
#        'type': 'artist',
#        'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/40VWCTZWMx12YUQxBZCJrR'},
#        'href': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR',
#        'id': '40VWCTZWMx12YUQxBZCJrR',
#        'name': 'Sujatha Dutt',
#        'type': 'artist',
#        'uri': 'spotify:artist:40VWCTZWMx12YUQxBZCJrR'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Eg5wFfEYY6DsiGelBYi4q'},
#        'href': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q',
#        'id': '1Eg5wFfEYY6DsiGelBYi4q',
#        'name': 'Krishna Tejasvi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Eg5wFfEYY6DsiGelBYi4q'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/45GzIiGfnR8atWLnqnjR96'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'},
#       'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ',
#       'id': '5VVN3xZw1i2qihfITZlvCZ',
#       'name': 'G. V. Prakash',
#       'type': 'artist',
#       'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/40VWCTZWMx12YUQxBZCJrR'},
#       'href': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR',
#       'id': '40VWCTZWMx12YUQxBZCJrR',
#       'name': 'Sujatha Dutt',
#       'type': 'artist',
#       'uri': 'spotify:artist:40VWCTZWMx12YUQxBZCJrR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Eg5wFfEYY6DsiGelBYi4q'},
#       'href': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q',
#       'id': '1Eg5wFfEYY6DsiGelBYi4q',
#       'name': 'Krishna Tejasvi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Eg5wFfEYY6DsiGelBYi4q'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 227085,
#     'external_ids': {'isrc': 'INA092419678'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6K24Qy0Zm1JoEDtHAUSSej'},
#     'href': 'https://api.spotify.com/v1/tracks/6K24Qy0Zm1JoEDtHAUSSej',
#     'id': '6K24Qy0Zm1JoEDtHAUSSej',
#     'name': 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)',
#     'popularity': 12,
#     'uri': 'spotify:track:6K24Qy0Zm1JoEDtHAUSSej',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-02-26T08:28:22Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31n3wir7uk5es22uv5dcseinv23i'},
#     'href': 'https://api.spotify.com/v1/users/31n3wir7uk5es22uv5dcseinv23i',
#     'id': '31n3wir7uk5es22uv5dcseinv23i',
#     'type': 'user',
#     'uri': 'spotify:user:31n3wir7uk5es22uv5dcseinv23i'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/6S5qpNyT3ZAg7m0e2XSOqx',
#      'id': '6S5qpNyT3ZAg7m0e2XSOqx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b0fe43ced529df9e3892ddc5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b0fe43ced529df9e3892ddc5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b0fe43ced529df9e3892ddc5',
#        'width': 64}],
#      'name': 'Vikram (Original Background Score)',
#      'release_date': '2022-07-07',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6S5qpNyT3ZAg7m0e2XSOqx',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#        'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#        'id': '4zCH9qm4R2DADamUHMCa6O',
#        'name': 'Anirudh Ravichander',
#        'type': 'artist',
#        'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6S5qpNyT3ZAg7m0e2XSOqx'},
#      'total_tracks': 21},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#       'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#       'id': '4zCH9qm4R2DADamUHMCa6O',
#       'name': 'Anirudh Ravichander',
#       'type': 'artist',
#       'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#     'disc_number': 1,
#     'track_number': 21,
#     'duration_ms': 53247,
#     'external_ids': {'isrc': 'INS172203321'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Vb8KkT6Ub5fFGPYJCJyLh'},
#     'href': 'https://api.spotify.com/v1/tracks/3Vb8KkT6Ub5fFGPYJCJyLh',
#     'id': '3Vb8KkT6Ub5fFGPYJCJyLh',
#     'name': 'Rolex Theme - Background Score',
#     'popularity': 53,
#     'uri': 'spotify:track:3Vb8KkT6Ub5fFGPYJCJyLh',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-02-26T08:28:23Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31n3wir7uk5es22uv5dcseinv23i'},
#     'href': 'https://api.spotify.com/v1/users/31n3wir7uk5es22uv5dcseinv23i',
#     'id': '31n3wir7uk5es22uv5dcseinv23i',
#     'type': 'user',
#     'uri': 'spotify:user:31n3wir7uk5es22uv5dcseinv23i'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/6S5qpNyT3ZAg7m0e2XSOqx',
#      'id': '6S5qpNyT3ZAg7m0e2XSOqx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b0fe43ced529df9e3892ddc5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b0fe43ced529df9e3892ddc5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b0fe43ced529df9e3892ddc5',
#        'width': 64}],
#      'name': 'Vikram (Original Background Score)',
#      'release_date': '2022-07-07',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6S5qpNyT3ZAg7m0e2XSOqx',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#        'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#        'id': '4zCH9qm4R2DADamUHMCa6O',
#        'name': 'Anirudh Ravichander',
#        'type': 'artist',
#        'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6S5qpNyT3ZAg7m0e2XSOqx'},
#      'total_tracks': 21},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#       'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#       'id': '4zCH9qm4R2DADamUHMCa6O',
#       'name': 'Anirudh Ravichander',
#       'type': 'artist',
#       'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#     'disc_number': 1,
#     'track_number': 20,
#     'duration_ms': 156330,
#     'external_ids': {'isrc': 'INS172203320'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/209pScL6fUhISxcLWkB6rf'},
#     'href': 'https://api.spotify.com/v1/tracks/209pScL6fUhISxcLWkB6rf',
#     'id': '209pScL6fUhISxcLWkB6rf',
#     'name': 'Lokiverse - Background Score',
#     'popularity': 57,
#     'uri': 'spotify:track:209pScL6fUhISxcLWkB6rf',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-02-26T08:33:18Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31n3wir7uk5es22uv5dcseinv23i'},
#     'href': 'https://api.spotify.com/v1/users/31n3wir7uk5es22uv5dcseinv23i',
#     'id': '31n3wir7uk5es22uv5dcseinv23i',
#     'type': 'user',
#     'uri': 'spotify:user:31n3wir7uk5es22uv5dcseinv23i'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/44qAUS0siEj2plisdS25xw',
#      'id': '44qAUS0siEj2plisdS25xw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bde3c2d2dcbee4dbd46b4e73',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bde3c2d2dcbee4dbd46b4e73',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bde3c2d2dcbee4dbd46b4e73',
#        'width': 64}],
#      'name': 'The Hunger Games: Mockingjay Pt. 1 (Original Motion Picture Score)',
#      'release_date': '2014-11-21',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:44qAUS0siEj2plisdS25xw',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2M4eNCvV3CJUswavkhAQg2'},
#        'href': 'https://api.spotify.com/v1/artists/2M4eNCvV3CJUswavkhAQg2',
#        'id': '2M4eNCvV3CJUswavkhAQg2',
#        'name': 'James Newton Howard',
#        'type': 'artist',
#        'uri': 'spotify:artist:2M4eNCvV3CJUswavkhAQg2'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/44qAUS0siEj2plisdS25xw'},
#      'total_tracks': 23},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2M4eNCvV3CJUswavkhAQg2'},
#       'href': 'https://api.spotify.com/v1/artists/2M4eNCvV3CJUswavkhAQg2',
#       'id': '2M4eNCvV3CJUswavkhAQg2',
#       'name': 'James Newton Howard',
#       'type': 'artist',
#       'uri': 'spotify:artist:2M4eNCvV3CJUswavkhAQg2'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3oCIYpmkFw8KGWwMNPKgXh'},
#       'href': 'https://api.spotify.com/v1/artists/3oCIYpmkFw8KGWwMNPKgXh',
#       'id': '3oCIYpmkFw8KGWwMNPKgXh',
#       'name': 'Jennifer Lawrence',
#       'type': 'artist',
#       'uri': 'spotify:artist:3oCIYpmkFw8KGWwMNPKgXh'}],
#     'disc_number': 1,
#     'track_number': 11,
#     'duration_ms': 218506,
#     'external_ids': {'isrc': 'USUG11401803'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/416MsJxvxSKY96DCmbJIRs'},
#     'href': 'https://api.spotify.com/v1/tracks/416MsJxvxSKY96DCmbJIRs',
#     'id': '416MsJxvxSKY96DCmbJIRs',
#     'name': 'The Hanging Tree',
#     'popularity': 65,
#     'uri': 'spotify:track:416MsJxvxSKY96DCmbJIRs',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2025-02-26T08:35:10Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31n3wir7uk5es22uv5dcseinv23i'},
#     'href': 'https://api.spotify.com/v1/users/31n3wir7uk5es22uv5dcseinv23i',
#     'id': '31n3wir7uk5es22uv5dcseinv23i',
#     'type': 'user',
#     'uri': 'spotify:user:31n3wir7uk5es22uv5dcseinv23i'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/0FIP7MeIO3yqL8K6uTz3b1',
#      'id': '0FIP7MeIO3yqL8K6uTz3b1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27339fe640ab73db368eeac0f90',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0239fe640ab73db368eeac0f90',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485139fe640ab73db368eeac0f90',
#        'width': 64}],
#      'name': 'Vikram (Original Motion Picture Soundtrack)',
#      'release_date': '2022-05-15',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0FIP7MeIO3yqL8K6uTz3b1',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#        'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#        'id': '4zCH9qm4R2DADamUHMCa6O',
#        'name': 'Anirudh Ravichander',
#        'type': 'artist',
#        'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0FIP7MeIO3yqL8K6uTz3b1'},
#      'total_tracks': 5},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#       'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#       'id': '4zCH9qm4R2DADamUHMCa6O',
#       'name': 'Anirudh Ravichander',
#       'type': 'artist',
#       'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 218823,
#     'external_ids': {'isrc': 'INS172201696'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6FQQiTpYnfc5803p84bQp1'},
#     'href': 'https://api.spotify.com/v1/tracks/6FQQiTpYnfc5803p84bQp1',
#     'id': '6FQQiTpYnfc5803p84bQp1',
#     'name': 'Vikram - Title Track',
#     'popularity': 57,
#     'uri': 'spotify:track:6FQQiTpYnfc5803p84bQp1',
#     'is_local': False},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 5}

# %%
data["items"]
# Out:
# [{'added_at': '2025-02-26T08:27:44Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31n3wir7uk5es22uv5dcseinv23i'},
#    'href': 'https://api.spotify.com/v1/users/31n3wir7uk5es22uv5dcseinv23i',
#    'id': '31n3wir7uk5es22uv5dcseinv23i',
#    'type': 'user',
#    'uri': 'spotify:user:31n3wir7uk5es22uv5dcseinv23i'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/45GzIiGfnR8atWLnqnjR96',
#     'id': '45GzIiGfnR8atWLnqnjR96',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273db317d407e81fcfaf7dfcd60',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02db317d407e81fcfaf7dfcd60',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851db317d407e81fcfaf7dfcd60',
#       'width': 64}],
#     'name': 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)',
#     'release_date': '2024-11-06',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:45GzIiGfnR8atWLnqnjR96',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'},
#       'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ',
#       'id': '5VVN3xZw1i2qihfITZlvCZ',
#       'name': 'G. V. Prakash',
#       'type': 'artist',
#       'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/40VWCTZWMx12YUQxBZCJrR'},
#       'href': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR',
#       'id': '40VWCTZWMx12YUQxBZCJrR',
#       'name': 'Sujatha Dutt',
#       'type': 'artist',
#       'uri': 'spotify:artist:40VWCTZWMx12YUQxBZCJrR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Eg5wFfEYY6DsiGelBYi4q'},
#       'href': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q',
#       'id': '1Eg5wFfEYY6DsiGelBYi4q',
#       'name': 'Krishna Tejasvi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Eg5wFfEYY6DsiGelBYi4q'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/45GzIiGfnR8atWLnqnjR96'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'},
#      'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ',
#      'id': '5VVN3xZw1i2qihfITZlvCZ',
#      'name': 'G. V. Prakash',
#      'type': 'artist',
#      'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/40VWCTZWMx12YUQxBZCJrR'},
#      'href': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR',
#      'id': '40VWCTZWMx12YUQxBZCJrR',
#      'name': 'Sujatha Dutt',
#      'type': 'artist',
#      'uri': 'spotify:artist:40VWCTZWMx12YUQxBZCJrR'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Eg5wFfEYY6DsiGelBYi4q'},
#      'href': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q',
#      'id': '1Eg5wFfEYY6DsiGelBYi4q',
#      'name': 'Krishna Tejasvi',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Eg5wFfEYY6DsiGelBYi4q'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 227085,
#    'external_ids': {'isrc': 'INA092419678'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6K24Qy0Zm1JoEDtHAUSSej'},
#    'href': 'https://api.spotify.com/v1/tracks/6K24Qy0Zm1JoEDtHAUSSej',
#    'id': '6K24Qy0Zm1JoEDtHAUSSej',
#    'name': 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)',
#    'popularity': 12,
#    'uri': 'spotify:track:6K24Qy0Zm1JoEDtHAUSSej',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2025-02-26T08:28:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31n3wir7uk5es22uv5dcseinv23i'},
#    'href': 'https://api.spotify.com/v1/users/31n3wir7uk5es22uv5dcseinv23i',
#    'id': '31n3wir7uk5es22uv5dcseinv23i',
#    'type': 'user',
#    'uri': 'spotify:user:31n3wir7uk5es22uv5dcseinv23i'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6S5qpNyT3ZAg7m0e2XSOqx',
#     'id': '6S5qpNyT3ZAg7m0e2XSOqx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b0fe43ced529df9e3892ddc5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b0fe43ced529df9e3892ddc5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b0fe43ced529df9e3892ddc5',
#       'width': 64}],
#     'name': 'Vikram (Original Background Score)',
#     'release_date': '2022-07-07',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6S5qpNyT3ZAg7m0e2XSOqx',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#       'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#       'id': '4zCH9qm4R2DADamUHMCa6O',
#       'name': 'Anirudh Ravichander',
#       'type': 'artist',
#       'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6S5qpNyT3ZAg7m0e2XSOqx'},
#     'total_tracks': 21},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#      'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#      'id': '4zCH9qm4R2DADamUHMCa6O',
#      'name': 'Anirudh Ravichander',
#      'type': 'artist',
#      'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#    'disc_number': 1,
#    'track_number': 21,
#    'duration_ms': 53247,
#    'external_ids': {'isrc': 'INS172203321'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3Vb8KkT6Ub5fFGPYJCJyLh'},
#    'href': 'https://api.spotify.com/v1/tracks/3Vb8KkT6Ub5fFGPYJCJyLh',
#    'id': '3Vb8KkT6Ub5fFGPYJCJyLh',
#    'name': 'Rolex Theme - Background Score',
#    'popularity': 53,
#    'uri': 'spotify:track:3Vb8KkT6Ub5fFGPYJCJyLh',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2025-02-26T08:28:23Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31n3wir7uk5es22uv5dcseinv23i'},
#    'href': 'https://api.spotify.com/v1/users/31n3wir7uk5es22uv5dcseinv23i',
#    'id': '31n3wir7uk5es22uv5dcseinv23i',
#    'type': 'user',
#    'uri': 'spotify:user:31n3wir7uk5es22uv5dcseinv23i'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/6S5qpNyT3ZAg7m0e2XSOqx',
#     'id': '6S5qpNyT3ZAg7m0e2XSOqx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b0fe43ced529df9e3892ddc5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b0fe43ced529df9e3892ddc5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b0fe43ced529df9e3892ddc5',
#       'width': 64}],
#     'name': 'Vikram (Original Background Score)',
#     'release_date': '2022-07-07',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6S5qpNyT3ZAg7m0e2XSOqx',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#       'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#       'id': '4zCH9qm4R2DADamUHMCa6O',
#       'name': 'Anirudh Ravichander',
#       'type': 'artist',
#       'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6S5qpNyT3ZAg7m0e2XSOqx'},
#     'total_tracks': 21},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#      'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#      'id': '4zCH9qm4R2DADamUHMCa6O',
#      'name': 'Anirudh Ravichander',
#      'type': 'artist',
#      'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#    'disc_number': 1,
#    'track_number': 20,
#    'duration_ms': 156330,
#    'external_ids': {'isrc': 'INS172203320'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/209pScL6fUhISxcLWkB6rf'},
#    'href': 'https://api.spotify.com/v1/tracks/209pScL6fUhISxcLWkB6rf',
#    'id': '209pScL6fUhISxcLWkB6rf',
#    'name': 'Lokiverse - Background Score',
#    'popularity': 57,
#    'uri': 'spotify:track:209pScL6fUhISxcLWkB6rf',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2025-02-26T08:33:18Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31n3wir7uk5es22uv5dcseinv23i'},
#    'href': 'https://api.spotify.com/v1/users/31n3wir7uk5es22uv5dcseinv23i',
#    'id': '31n3wir7uk5es22uv5dcseinv23i',
#    'type': 'user',
#    'uri': 'spotify:user:31n3wir7uk5es22uv5dcseinv23i'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/44qAUS0siEj2plisdS25xw',
#     'id': '44qAUS0siEj2plisdS25xw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bde3c2d2dcbee4dbd46b4e73',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bde3c2d2dcbee4dbd46b4e73',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bde3c2d2dcbee4dbd46b4e73',
#       'width': 64}],
#     'name': 'The Hunger Games: Mockingjay Pt. 1 (Original Motion Picture Score)',
#     'release_date': '2014-11-21',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:44qAUS0siEj2plisdS25xw',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2M4eNCvV3CJUswavkhAQg2'},
#       'href': 'https://api.spotify.com/v1/artists/2M4eNCvV3CJUswavkhAQg2',
#       'id': '2M4eNCvV3CJUswavkhAQg2',
#       'name': 'James Newton Howard',
#       'type': 'artist',
#       'uri': 'spotify:artist:2M4eNCvV3CJUswavkhAQg2'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44qAUS0siEj2plisdS25xw'},
#     'total_tracks': 23},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2M4eNCvV3CJUswavkhAQg2'},
#      'href': 'https://api.spotify.com/v1/artists/2M4eNCvV3CJUswavkhAQg2',
#      'id': '2M4eNCvV3CJUswavkhAQg2',
#      'name': 'James Newton Howard',
#      'type': 'artist',
#      'uri': 'spotify:artist:2M4eNCvV3CJUswavkhAQg2'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3oCIYpmkFw8KGWwMNPKgXh'},
#      'href': 'https://api.spotify.com/v1/artists/3oCIYpmkFw8KGWwMNPKgXh',
#      'id': '3oCIYpmkFw8KGWwMNPKgXh',
#      'name': 'Jennifer Lawrence',
#      'type': 'artist',
#      'uri': 'spotify:artist:3oCIYpmkFw8KGWwMNPKgXh'}],
#    'disc_number': 1,
#    'track_number': 11,
#    'duration_ms': 218506,
#    'external_ids': {'isrc': 'USUG11401803'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/416MsJxvxSKY96DCmbJIRs'},
#    'href': 'https://api.spotify.com/v1/tracks/416MsJxvxSKY96DCmbJIRs',
#    'id': '416MsJxvxSKY96DCmbJIRs',
#    'name': 'The Hanging Tree',
#    'popularity': 65,
#    'uri': 'spotify:track:416MsJxvxSKY96DCmbJIRs',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2025-02-26T08:35:10Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31n3wir7uk5es22uv5dcseinv23i'},
#    'href': 'https://api.spotify.com/v1/users/31n3wir7uk5es22uv5dcseinv23i',
#    'id': '31n3wir7uk5es22uv5dcseinv23i',
#    'type': 'user',
#    'uri': 'spotify:user:31n3wir7uk5es22uv5dcseinv23i'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/0FIP7MeIO3yqL8K6uTz3b1',
#     'id': '0FIP7MeIO3yqL8K6uTz3b1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27339fe640ab73db368eeac0f90',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0239fe640ab73db368eeac0f90',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485139fe640ab73db368eeac0f90',
#       'width': 64}],
#     'name': 'Vikram (Original Motion Picture Soundtrack)',
#     'release_date': '2022-05-15',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:0FIP7MeIO3yqL8K6uTz3b1',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#       'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#       'id': '4zCH9qm4R2DADamUHMCa6O',
#       'name': 'Anirudh Ravichander',
#       'type': 'artist',
#       'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0FIP7MeIO3yqL8K6uTz3b1'},
#     'total_tracks': 5},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'},
#      'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#      'id': '4zCH9qm4R2DADamUHMCa6O',
#      'name': 'Anirudh Ravichander',
#      'type': 'artist',
#      'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 218823,
#    'external_ids': {'isrc': 'INS172201696'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6FQQiTpYnfc5803p84bQp1'},
#    'href': 'https://api.spotify.com/v1/tracks/6FQQiTpYnfc5803p84bQp1',
#    'id': '6FQQiTpYnfc5803p84bQp1',
#    'name': 'Vikram - Title Track',
#    'popularity': 57,
#    'uri': 'spotify:track:6FQQiTpYnfc5803p84bQp1',
#    'is_local': False},
#   'video_thumbnail': {'url': None}}]

# %%
data["items"][0]
# Out:
# {'added_at': '2025-02-26T08:27:44Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31n3wir7uk5es22uv5dcseinv23i'},
#   'href': 'https://api.spotify.com/v1/users/31n3wir7uk5es22uv5dcseinv23i',
#   'id': '31n3wir7uk5es22uv5dcseinv23i',
#   'type': 'user',
#   'uri': 'spotify:user:31n3wir7uk5es22uv5dcseinv23i'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'type': 'album',
#    'album_type': 'single',
#    'href': 'https://api.spotify.com/v1/albums/45GzIiGfnR8atWLnqnjR96',
#    'id': '45GzIiGfnR8atWLnqnjR96',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273db317d407e81fcfaf7dfcd60',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02db317d407e81fcfaf7dfcd60',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851db317d407e81fcfaf7dfcd60',
#      'width': 64}],
#    'name': 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)',
#    'release_date': '2024-11-06',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:45GzIiGfnR8atWLnqnjR96',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'},
#      'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ',
#      'id': '5VVN3xZw1i2qihfITZlvCZ',
#      'name': 'G. V. Prakash',
#      'type': 'artist',
#      'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/40VWCTZWMx12YUQxBZCJrR'},
#      'href': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR',
#      'id': '40VWCTZWMx12YUQxBZCJrR',
#      'name': 'Sujatha Dutt',
#      'type': 'artist',
#      'uri': 'spotify:artist:40VWCTZWMx12YUQxBZCJrR'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Eg5wFfEYY6DsiGelBYi4q'},
#      'href': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q',
#      'id': '1Eg5wFfEYY6DsiGelBYi4q',
#      'name': 'Krishna Tejasvi',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Eg5wFfEYY6DsiGelBYi4q'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/45GzIiGfnR8atWLnqnjR96'},
#    'total_tracks': 1},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'},
#     'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ',
#     'id': '5VVN3xZw1i2qihfITZlvCZ',
#     'name': 'G. V. Prakash',
#     'type': 'artist',
#     'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/40VWCTZWMx12YUQxBZCJrR'},
#     'href': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR',
#     'id': '40VWCTZWMx12YUQxBZCJrR',
#     'name': 'Sujatha Dutt',
#     'type': 'artist',
#     'uri': 'spotify:artist:40VWCTZWMx12YUQxBZCJrR'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Eg5wFfEYY6DsiGelBYi4q'},
#     'href': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q',
#     'id': '1Eg5wFfEYY6DsiGelBYi4q',
#     'name': 'Krishna Tejasvi',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Eg5wFfEYY6DsiGelBYi4q'}],
#   'disc_number': 1,
#   'track_number': 1,
#   'duration_ms': 227085,
#   'external_ids': {'isrc': 'INA092419678'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6K24Qy0Zm1JoEDtHAUSSej'},
#   'href': 'https://api.spotify.com/v1/tracks/6K24Qy0Zm1JoEDtHAUSSej',
#   'id': '6K24Qy0Zm1JoEDtHAUSSej',
#   'name': 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)',
#   'popularity': 12,
#   'uri': 'spotify:track:6K24Qy0Zm1JoEDtHAUSSej',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
len(data["items"])
# Out:
# 5

# %%
data["items"][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'PR',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'explicit': False,
#  'type': 'track',
#  'episode': False,
#  'track': True,
#  'album': {'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'type': 'album',
#   'album_type': 'single',
#   'href': 'https://api.spotify.com/v1/albums/45GzIiGfnR8atWLnqnjR96',
#   'id': '45GzIiGfnR8atWLnqnjR96',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273db317d407e81fcfaf7dfcd60',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02db317d407e81fcfaf7dfcd60',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851db317d407e81fcfaf7dfcd60',
#     'width': 64}],
#   'name': 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)',
#   'release_date': '2024-11-06',
#   'release_date_precision': 'day',
#   'uri': 'spotify:album:45GzIiGfnR8atWLnqnjR96',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'},
#     'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ',
#     'id': '5VVN3xZw1i2qihfITZlvCZ',
#     'name': 'G. V. Prakash',
#     'type': 'artist',
#     'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/40VWCTZWMx12YUQxBZCJrR'},
#     'href': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR',
#     'id': '40VWCTZWMx12YUQxBZCJrR',
#     'name': 'Sujatha Dutt',
#     'type': 'artist',
#     'uri': 'spotify:artist:40VWCTZWMx12YUQxBZCJrR'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Eg5wFfEYY6DsiGelBYi4q'},
#     'href': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q',
#     'id': '1Eg5wFfEYY6DsiGelBYi4q',
#     'name': 'Krishna Tejasvi',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Eg5wFfEYY6DsiGelBYi4q'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/45GzIiGfnR8atWLnqnjR96'},
#   'total_tracks': 1},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'},
#    'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ',
#    'id': '5VVN3xZw1i2qihfITZlvCZ',
#    'name': 'G. V. Prakash',
#    'type': 'artist',
#    'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/40VWCTZWMx12YUQxBZCJrR'},
#    'href': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR',
#    'id': '40VWCTZWMx12YUQxBZCJrR',
#    'name': 'Sujatha Dutt',
#    'type': 'artist',
#    'uri': 'spotify:artist:40VWCTZWMx12YUQxBZCJrR'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Eg5wFfEYY6DsiGelBYi4q'},
#    'href': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q',
#    'id': '1Eg5wFfEYY6DsiGelBYi4q',
#    'name': 'Krishna Tejasvi',
#    'type': 'artist',
#    'uri': 'spotify:artist:1Eg5wFfEYY6DsiGelBYi4q'}],
#  'disc_number': 1,
#  'track_number': 1,
#  'duration_ms': 227085,
#  'external_ids': {'isrc': 'INA092419678'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/6K24Qy0Zm1JoEDtHAUSSej'},
#  'href': 'https://api.spotify.com/v1/tracks/6K24Qy0Zm1JoEDtHAUSSej',
#  'id': '6K24Qy0Zm1JoEDtHAUSSej',
#  'name': 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)',
#  'popularity': 12,
#  'uri': 'spotify:track:6K24Qy0Zm1JoEDtHAUSSej',
#  'is_local': False}

# %%
data["items"][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'PR',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'type': 'album',
#  'album_type': 'single',
#  'href': 'https://api.spotify.com/v1/albums/45GzIiGfnR8atWLnqnjR96',
#  'id': '45GzIiGfnR8atWLnqnjR96',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273db317d407e81fcfaf7dfcd60',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02db317d407e81fcfaf7dfcd60',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851db317d407e81fcfaf7dfcd60',
#    'width': 64}],
#  'name': 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)',
#  'release_date': '2024-11-06',
#  'release_date_precision': 'day',
#  'uri': 'spotify:album:45GzIiGfnR8atWLnqnjR96',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'},
#    'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ',
#    'id': '5VVN3xZw1i2qihfITZlvCZ',
#    'name': 'G. V. Prakash',
#    'type': 'artist',
#    'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/40VWCTZWMx12YUQxBZCJrR'},
#    'href': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR',
#    'id': '40VWCTZWMx12YUQxBZCJrR',
#    'name': 'Sujatha Dutt',
#    'type': 'artist',
#    'uri': 'spotify:artist:40VWCTZWMx12YUQxBZCJrR'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Eg5wFfEYY6DsiGelBYi4q'},
#    'href': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q',
#    'id': '1Eg5wFfEYY6DsiGelBYi4q',
#    'name': 'Krishna Tejasvi',
#    'type': 'artist',
#    'uri': 'spotify:artist:1Eg5wFfEYY6DsiGelBYi4q'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/45GzIiGfnR8atWLnqnjR96'},
#  'total_tracks': 1}

# %%
data["items"][0]['track']['album']['id']
# Out:
# '45GzIiGfnR8atWLnqnjR96'

# %%
data["items"][0]['track']['album']['name']
# Out:
# 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)'

# %%
data["items"][0]['track']['album']['release_date']
# Out:
# '2024-11-06'

# %%
data["items"][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data["items"][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/45GzIiGfnR8atWLnqnjR96'

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    print(album_id)
    print(album_name)
    print(album_release_date)
    print(album_total_tracks)
    print(album_url)
# Out:
# 45GzIiGfnR8atWLnqnjR96
# Nijavaa Idoo (From "Lucky Baskhar")(Kannada)
# 2024-11-06
# 1
# https://open.spotify.com/album/45GzIiGfnR8atWLnqnjR96
# 6S5qpNyT3ZAg7m0e2XSOqx
# Vikram (Original Background Score)
# 2022-07-07
# 21
# https://open.spotify.com/album/6S5qpNyT3ZAg7m0e2XSOqx
# 6S5qpNyT3ZAg7m0e2XSOqx
# Vikram (Original Background Score)
# 2022-07-07
# 21
# https://open.spotify.com/album/6S5qpNyT3ZAg7m0e2XSOqx
# 44qAUS0siEj2plisdS25xw
# The Hunger Games: Mockingjay Pt. 1 (Original Motion Picture Score)
# 2014-11-21
# 23
# https://open.spotify.com/album/44qAUS0siEj2plisdS25xw
# 0FIP7MeIO3yqL8K6uTz3b1
# Vikram (Original Motion Picture Soundtrack)
# 2022-05-15
# 5
# https://open.spotify.com/album/0FIP7MeIO3yqL8K6uTz3b1

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_elements = {'album_id':album_id,'name':album_name,'release_date':album_release_date,'total_tracks':album_total_tracks,'url':album_url}
    print(album_elements)
# Out:
# {'album_id': '45GzIiGfnR8atWLnqnjR96', 'name': 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)', 'release_date': '2024-11-06', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/45GzIiGfnR8atWLnqnjR96'}
# {'album_id': '6S5qpNyT3ZAg7m0e2XSOqx', 'name': 'Vikram (Original Background Score)', 'release_date': '2022-07-07', 'total_tracks': 21, 'url': 'https://open.spotify.com/album/6S5qpNyT3ZAg7m0e2XSOqx'}
# {'album_id': '6S5qpNyT3ZAg7m0e2XSOqx', 'name': 'Vikram (Original Background Score)', 'release_date': '2022-07-07', 'total_tracks': 21, 'url': 'https://open.spotify.com/album/6S5qpNyT3ZAg7m0e2XSOqx'}
# {'album_id': '44qAUS0siEj2plisdS25xw', 'name': 'The Hunger Games: Mockingjay Pt. 1 (Original Motion Picture Score)', 'release_date': '2014-11-21', 'total_tracks': 23, 'url': 'https://open.spotify.com/album/44qAUS0siEj2plisdS25xw'}
# {'album_id': '0FIP7MeIO3yqL8K6uTz3b1', 'name': 'Vikram (Original Motion Picture Soundtrack)', 'release_date': '2022-05-15', 'total_tracks': 5, 'url': 'https://open.spotify.com/album/0FIP7MeIO3yqL8K6uTz3b1'}

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_elements = {'album_id':album_id,'name':album_name,'release_date':album_release_date,'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '45GzIiGfnR8atWLnqnjR96',
#   'name': 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)',
#   'release_date': '2024-11-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/45GzIiGfnR8atWLnqnjR96'},
#  {'album_id': '6S5qpNyT3ZAg7m0e2XSOqx',
#   'name': 'Vikram (Original Background Score)',
#   'release_date': '2022-07-07',
#   'total_tracks': 21,
#   'url': 'https://open.spotify.com/album/6S5qpNyT3ZAg7m0e2XSOqx'},
#  {'album_id': '6S5qpNyT3ZAg7m0e2XSOqx',
#   'name': 'Vikram (Original Background Score)',
#   'release_date': '2022-07-07',
#   'total_tracks': 21,
#   'url': 'https://open.spotify.com/album/6S5qpNyT3ZAg7m0e2XSOqx'},
#  {'album_id': '44qAUS0siEj2plisdS25xw',
#   'name': 'The Hunger Games: Mockingjay Pt. 1 (Original Motion Picture Score)',
#   'release_date': '2014-11-21',
#   'total_tracks': 23,
#   'url': 'https://open.spotify.com/album/44qAUS0siEj2plisdS25xw'},
#  {'album_id': '0FIP7MeIO3yqL8K6uTz3b1',
#   'name': 'Vikram (Original Motion Picture Soundtrack)',
#   'release_date': '2022-05-15',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/0FIP7MeIO3yqL8K6uTz3b1'}]

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'},
#   'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ',
#   'id': '5VVN3xZw1i2qihfITZlvCZ',
#   'name': 'G. V. Prakash',
#   'type': 'artist',
#   'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/40VWCTZWMx12YUQxBZCJrR'},
#   'href': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR',
#   'id': '40VWCTZWMx12YUQxBZCJrR',
#   'name': 'Sujatha Dutt',
#   'type': 'artist',
#   'uri': 'spotify:artist:40VWCTZWMx12YUQxBZCJrR'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Eg5wFfEYY6DsiGelBYi4q'},
#   'href': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q',
#   'id': '1Eg5wFfEYY6DsiGelBYi4q',
#   'name': 'Krishna Tejasvi',
#   'type': 'artist',
#   'uri': 'spotify:artist:1Eg5wFfEYY6DsiGelBYi4q'}]

# %%
data['items'][0]['track']['artists'][0]['id']
# Out:
# '5VVN3xZw1i2qihfITZlvCZ'

# %%
for row in data['items']:
    for key,value in row.items():
        if key == "track":
            print(value)
# Out:
# {'preview_url': None, 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'explicit': False, 'type': 'track', 'episode': False, 'track': True, 'album': {'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'type': 'album', 'album_type': 'single', 'href': 'https://api.spotify.com/v1/albums/45GzIiGfnR8atWLnqnjR96', 'id': '45GzIiGfnR8atWLnqnjR96', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273db317d407e81fcfaf7dfcd60', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02db317d407e81fcfaf7dfcd60', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851db317d407e81fcfaf7dfcd60', 'width': 64}], 'name': 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)', 'release_date': '2024-11-06', 'release_date_precision': 'day', 'uri': 'spotify:album:45GzIiGfnR8atWLnqnjR96', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'}, 'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ', 'id': '5VVN3xZw1i2qihfITZlvCZ', 'name': 'G. V. Prakash', 'type': 'artist', 'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/40VWCTZWMx12YUQxBZCJrR'}, 'href': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR', 'id': '40VWCTZWMx12YUQxBZCJrR', 'name': 'Sujatha Dutt', 'type': 'artist', 'uri': 'spotify:artist:40VWCTZWMx12YUQxBZCJrR'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Eg5wFfEYY6DsiGelBYi4q'}, 'href': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q', 'id': '1Eg5wFfEYY6DsiGelBYi4q', 'name': 'Krishna Tejasvi', 'type': 'artist', 'uri': 'spotify:artist:1Eg5wFfEYY6DsiGelBYi4q'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/45GzIiGfnR8atWLnqnjR96'}, 'total_tracks': 1}, 'artists': [{'external_urls': { ...
# {'preview_url': None, 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'explicit': False, 'type': 'track', 'episode': False, 'track': True, 'album': {'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'type': 'album', 'album_type': 'album', 'href': 'https://api.spotify.com/v1/albums/6S5qpNyT3ZAg7m0e2XSOqx', 'id': '6S5qpNyT3ZAg7m0e2XSOqx', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273b0fe43ced529df9e3892ddc5', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02b0fe43ced529df9e3892ddc5', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851b0fe43ced529df9e3892ddc5', 'width': 64}], 'name': 'Vikram (Original Background Score)', 'release_date': '2022-07-07', 'release_date_precision': 'day', 'uri': 'spotify:album:6S5qpNyT3ZAg7m0e2XSOqx', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}, 'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O', 'id': '4zCH9qm4R2DADamUHMCa6O', 'name': 'Anirudh Ravichander', 'type': 'artist', 'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/6S5qpNyT3ZAg7m0e2XSOqx'}, 'total_tracks': 21}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}, 'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O', 'id': '4zCH9qm4R2DADamUHMCa6O', 'name': 'Anirudh Ravichander', 'type': 'artist', 'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}], 'disc_number': 1, 'track_number': 21, 'duration_ms': 53247, 'external_ids': {'isrc': 'INS172203321'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/3Vb8KkT6Ub5fFGPYJCJyLh'}, 'href': 'https://api.spotify.com/v1/tracks/3Vb8KkT6Ub5fFGPYJCJyLh', 'id': '3Vb8KkT6Ub5fFGPYJCJyLh', 'name': 'R ...
# {'preview_url': None, 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'explicit': False, 'type': 'track', 'episode': False, 'track': True, 'album': {'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'type': 'album', 'album_type': 'album', 'href': 'https://api.spotify.com/v1/albums/6S5qpNyT3ZAg7m0e2XSOqx', 'id': '6S5qpNyT3ZAg7m0e2XSOqx', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273b0fe43ced529df9e3892ddc5', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02b0fe43ced529df9e3892ddc5', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851b0fe43ced529df9e3892ddc5', 'width': 64}], 'name': 'Vikram (Original Background Score)', 'release_date': '2022-07-07', 'release_date_precision': 'day', 'uri': 'spotify:album:6S5qpNyT3ZAg7m0e2XSOqx', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}, 'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O', 'id': '4zCH9qm4R2DADamUHMCa6O', 'name': 'Anirudh Ravichander', 'type': 'artist', 'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/6S5qpNyT3ZAg7m0e2XSOqx'}, 'total_tracks': 21}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}, 'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O', 'id': '4zCH9qm4R2DADamUHMCa6O', 'name': 'Anirudh Ravichander', 'type': 'artist', 'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}], 'disc_number': 1, 'track_number': 20, 'duration_ms': 156330, 'external_ids': {'isrc': 'INS172203320'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/209pScL6fUhISxcLWkB6rf'}, 'href': 'https://api.spotify.com/v1/tracks/209pScL6fUhISxcLWkB6rf', 'id': '209pScL6fUhISxcLWkB6rf', 'name': ' ...
# {'preview_url': None, 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'XK'], 'explicit': False, 'type': 'track', 'episode': False, 'track': True, 'album': {'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'XK'], 'type': 'album', 'album_type': 'album', 'href': 'https://api.spotify.com/v1/albums/44qAUS0siEj2plisdS25xw', 'id': '44qAUS0siEj2plisdS25xw', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273bde3c2d2dcbee4dbd46b4e73', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02bde3c2d2dcbee4dbd46b4e73', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851bde3c2d2dcbee4dbd46b4e73', 'width': 64}], 'name': 'The Hunger Games: Mockingjay Pt. 1 (Original Motion Picture Score)', 'release_date': '2014-11-21', 'release_date_precision': 'day', 'uri': 'spotify:album:44qAUS0siEj2plisdS25xw', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2M4eNCvV3CJUswavkhAQg2'}, 'href': 'https://api.spotify.com/v1/artists/2M4eNCvV3CJUswavkhAQg2', 'id': '2M4eNCvV3CJUswavkhAQg2', 'name': 'James Newton Howard', 'type': 'artist', 'uri': 'spotify:artist:2M4eNCvV3CJUswavkhAQg2'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/44qAUS0siEj2plisdS25xw'}, 'total_tracks': 23}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2M4eNCvV3CJUswavkhAQg2'}, 'href': 'https://api.spotify.com/v1/artists/2M4eNCvV3CJUswavkhAQg2', 'id': '2M4eNCvV3CJUswavkhAQg2', 'name': 'James Newton Howard', 'type': 'artist', 'uri': 'spotify:artist:2M4eNCvV3CJUswavkhAQg2'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3oCIYpmkFw8KGWwMNPKgXh'}, 'href': 'https://api.spotify.com/v1/artists/3oCIYpmkFw8KGWwMNPKgXh', 'id': '3oCIYpmkFw8KGWwMNPKgXh', 'name': 'Jennifer Lawrence', 'type': 'artist', 'uri': 'spotify:artist:3oCIYpmkFw8KGWwMNPKgXh'}], 'disc ...
# {'preview_url': None, 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'explicit': False, 'type': 'track', 'episode': False, 'track': True, 'album': {'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'type': 'album', 'album_type': 'single', 'href': 'https://api.spotify.com/v1/albums/0FIP7MeIO3yqL8K6uTz3b1', 'id': '0FIP7MeIO3yqL8K6uTz3b1', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27339fe640ab73db368eeac0f90', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0239fe640ab73db368eeac0f90', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485139fe640ab73db368eeac0f90', 'width': 64}], 'name': 'Vikram (Original Motion Picture Soundtrack)', 'release_date': '2022-05-15', 'release_date_precision': 'day', 'uri': 'spotify:album:0FIP7MeIO3yqL8K6uTz3b1', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}, 'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O', 'id': '4zCH9qm4R2DADamUHMCa6O', 'name': 'Anirudh Ravichander', 'type': 'artist', 'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/0FIP7MeIO3yqL8K6uTz3b1'}, 'total_tracks': 5}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}, 'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O', 'id': '4zCH9qm4R2DADamUHMCa6O', 'name': 'Anirudh Ravichander', 'type': 'artist', 'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}], 'disc_number': 1, 'track_number': 2, 'duration_ms': 218823, 'external_ids': {'isrc': 'INS172201696'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6FQQiTpYnfc5803p84bQp1'}, 'href': 'https://api.spotify.com/v1/tracks/6FQQiTpYnfc5803p84bQp1', 'id': '6FQQiTpYnfc5803p84bQp1', ' ...

# %%
for row in data['items']:
    for key,value in row.items():
        if key == "track":
            print(value['artists'])
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'}, 'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ', 'id': '5VVN3xZw1i2qihfITZlvCZ', 'name': 'G. V. Prakash', 'type': 'artist', 'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/40VWCTZWMx12YUQxBZCJrR'}, 'href': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR', 'id': '40VWCTZWMx12YUQxBZCJrR', 'name': 'Sujatha Dutt', 'type': 'artist', 'uri': 'spotify:artist:40VWCTZWMx12YUQxBZCJrR'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Eg5wFfEYY6DsiGelBYi4q'}, 'href': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q', 'id': '1Eg5wFfEYY6DsiGelBYi4q', 'name': 'Krishna Tejasvi', 'type': 'artist', 'uri': 'spotify:artist:1Eg5wFfEYY6DsiGelBYi4q'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}, 'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O', 'id': '4zCH9qm4R2DADamUHMCa6O', 'name': 'Anirudh Ravichander', 'type': 'artist', 'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}, 'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O', 'id': '4zCH9qm4R2DADamUHMCa6O', 'name': 'Anirudh Ravichander', 'type': 'artist', 'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2M4eNCvV3CJUswavkhAQg2'}, 'href': 'https://api.spotify.com/v1/artists/2M4eNCvV3CJUswavkhAQg2', 'id': '2M4eNCvV3CJUswavkhAQg2', 'name': 'James Newton Howard', 'type': 'artist', 'uri': 'spotify:artist:2M4eNCvV3CJUswavkhAQg2'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3oCIYpmkFw8KGWwMNPKgXh'}, 'href': 'https://api.spotify.com/v1/artists/3oCIYpmkFw8KGWwMNPKgXh', 'id': '3oCIYpmkFw8KGWwMNPKgXh', 'name': 'Jennifer Lawrence', 'type': 'artist', 'uri': 'spotify:artist:3oCIYpmkFw8KGWwMNPKgXh'}]
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}, 'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O', 'id': '4zCH9qm4R2DADamUHMCa6O', 'name': 'Anirudh Ravichander', 'type': 'artist', 'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}]

# %%
for row in data['items']:
    for key,value in row.items():
        if key == "track":
            for artist in value['artists']:
                print(artist)
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5VVN3xZw1i2qihfITZlvCZ'}, 'href': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ', 'id': '5VVN3xZw1i2qihfITZlvCZ', 'name': 'G. V. Prakash', 'type': 'artist', 'uri': 'spotify:artist:5VVN3xZw1i2qihfITZlvCZ'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/40VWCTZWMx12YUQxBZCJrR'}, 'href': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR', 'id': '40VWCTZWMx12YUQxBZCJrR', 'name': 'Sujatha Dutt', 'type': 'artist', 'uri': 'spotify:artist:40VWCTZWMx12YUQxBZCJrR'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1Eg5wFfEYY6DsiGelBYi4q'}, 'href': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q', 'id': '1Eg5wFfEYY6DsiGelBYi4q', 'name': 'Krishna Tejasvi', 'type': 'artist', 'uri': 'spotify:artist:1Eg5wFfEYY6DsiGelBYi4q'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}, 'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O', 'id': '4zCH9qm4R2DADamUHMCa6O', 'name': 'Anirudh Ravichander', 'type': 'artist', 'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}, 'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O', 'id': '4zCH9qm4R2DADamUHMCa6O', 'name': 'Anirudh Ravichander', 'type': 'artist', 'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/2M4eNCvV3CJUswavkhAQg2'}, 'href': 'https://api.spotify.com/v1/artists/2M4eNCvV3CJUswavkhAQg2', 'id': '2M4eNCvV3CJUswavkhAQg2', 'name': 'James Newton Howard', 'type': 'artist', 'uri': 'spotify:artist:2M4eNCvV3CJUswavkhAQg2'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3oCIYpmkFw8KGWwMNPKgXh'}, 'href': 'https://api.spotify.com/v1/artists/3oCIYpmkFw8KGWwMNPKgXh', 'id': '3oCIYpmkFw8KGWwMNPKgXh', 'name': 'Jennifer Lawrence', 'type': 'artist', 'uri': 'spotify:artist:3oCIYpmkFw8KGWwMNPKgXh'}
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4zCH9qm4R2DADamUHMCa6O'}, 'href': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O', 'id': '4zCH9qm4R2DADamUHMCa6O', 'name': 'Anirudh Ravichander', 'type': 'artist', 'uri': 'spotify:artist:4zCH9qm4R2DADamUHMCa6O'}

# %%
for row in data['items']:
    for key,value in row.items():
        if key == "track":
            for artist in value['artists']:
                print(artist['id'])
# Out:
# 5VVN3xZw1i2qihfITZlvCZ
# 40VWCTZWMx12YUQxBZCJrR
# 1Eg5wFfEYY6DsiGelBYi4q
# 4zCH9qm4R2DADamUHMCa6O
# 4zCH9qm4R2DADamUHMCa6O
# 2M4eNCvV3CJUswavkhAQg2
# 3oCIYpmkFw8KGWwMNPKgXh
# 4zCH9qm4R2DADamUHMCa6O

# %%
artist_list = []
for row in data['items']:
    for key,value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '5VVN3xZw1i2qihfITZlvCZ',
#   'artist_name': 'G. V. Prakash',
#   'external_url': 'https://api.spotify.com/v1/artists/5VVN3xZw1i2qihfITZlvCZ'},
#  {'artist_id': '40VWCTZWMx12YUQxBZCJrR',
#   'artist_name': 'Sujatha Dutt',
#   'external_url': 'https://api.spotify.com/v1/artists/40VWCTZWMx12YUQxBZCJrR'},
#  {'artist_id': '1Eg5wFfEYY6DsiGelBYi4q',
#   'artist_name': 'Krishna Tejasvi',
#   'external_url': 'https://api.spotify.com/v1/artists/1Eg5wFfEYY6DsiGelBYi4q'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'external_url': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'external_url': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'},
#  {'artist_id': '2M4eNCvV3CJUswavkhAQg2',
#   'artist_name': 'James Newton Howard',
#   'external_url': 'https://api.spotify.com/v1/artists/2M4eNCvV3CJUswavkhAQg2'},
#  {'artist_id': '3oCIYpmkFw8KGWwMNPKgXh',
#   'artist_name': 'Jennifer Lawrence',
#   'external_url': 'https://api.spotify.com/v1/artists/3oCIYpmkFw8KGWwMNPKgXh'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'external_url': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,'popularity':song_popularity,'song_added':song_added,'album_id':album_id,'artist_id':artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '6K24Qy0Zm1JoEDtHAUSSej',
#   'song_name': 'Nijavaa Idoo (From "Lucky Baskhar")(Kannada)',
#   'duration_ms': 227085,
#   'url': 'https://open.spotify.com/track/6K24Qy0Zm1JoEDtHAUSSej',
#   'popularity': 12,
#   'song_added': '2025-02-26T08:27:44Z',
#   'album_id': '45GzIiGfnR8atWLnqnjR96',
#   'artist_id': '5VVN3xZw1i2qihfITZlvCZ'},
#  {'song_id': '3Vb8KkT6Ub5fFGPYJCJyLh',
#   'song_name': 'Rolex Theme - Background Score',
#   'duration_ms': 53247,
#   'url': 'https://open.spotify.com/track/3Vb8KkT6Ub5fFGPYJCJyLh',
#   'popularity': 53,
#   'song_added': '2025-02-26T08:28:22Z',
#   'album_id': '6S5qpNyT3ZAg7m0e2XSOqx',
#   'artist_id': '4zCH9qm4R2DADamUHMCa6O'},
#  {'song_id': '209pScL6fUhISxcLWkB6rf',
#   'song_name': 'Lokiverse - Background Score',
#   'duration_ms': 156330,
#   'url': 'https://open.spotify.com/track/209pScL6fUhISxcLWkB6rf',
#   'popularity': 57,
#   'song_added': '2025-02-26T08:28:23Z',
#   'album_id': '6S5qpNyT3ZAg7m0e2XSOqx',
#   'artist_id': '4zCH9qm4R2DADamUHMCa6O'},
#  {'song_id': '416MsJxvxSKY96DCmbJIRs',
#   'song_name': 'The Hanging Tree',
#   'duration_ms': 218506,
#   'url': 'https://open.spotify.com/track/416MsJxvxSKY96DCmbJIRs',
#   'popularity': 65,
#   'song_added': '2025-02-26T08:33:18Z',
#   'album_id': '44qAUS0siEj2plisdS25xw',
#   'artist_id': '2M4eNCvV3CJUswavkhAQg2'},
#  {'song_id': '6FQQiTpYnfc5803p84bQp1',
#   'song_name': 'Vikram - Title Track',
#   'duration_ms': 218823,
#   'url': 'https://open.spotify.com/track/6FQQiTpYnfc5803p84bQp1',
#   'popularity': 57,
#   'song_added': '2025-02-26T08:35:10Z',
#   'album_id': '0FIP7MeIO3yqL8K6uTz3b1',
#   'artist_id': '4zCH9qm4R2DADamUHMCa6O'}]

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  45GzIiGfnR8atWLnqnjR96       Nijavaa Idoo (From "Lucky Baskhar")(Kannada)
# 1  6S5qpNyT3ZAg7m0e2XSOqx                 Vikram (Original Background Score)
# 2  6S5qpNyT3ZAg7m0e2XSOqx                 Vikram (Original Background Score)
# 3  44qAUS0siEj2plisdS25xw  The Hunger Games: Mockingjay Pt. 1 (Original M...
# 4  0FIP7MeIO3yqL8K6uTz3b1        Vikram (Original Motion Picture Soundtrack)
#
#   release_date  total_tracks  \
# 0   2024-11-06             1
# 1   2022-07-07            21
# 2   2022-07-07            21
# 3   2014-11-21            23
# 4   2022-05-15             5
#
#                                                  url
# 0  https://open.spotify.com/album/45GzIiGfnR8atWL...
# 1  https://open.spotify.com/album/6S5qpNyT3ZAg7m0...
# 2  https://open.spotify.com/album/6S5qpNyT3ZAg7m0...
# 3  https://open.spotify.com/album/44qAUS0siEj2pli...
# 4  https://open.spotify.com/album/0FIP7MeIO3yqL8K...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      5 non-null      object
#  1   name          5 non-null      object
#  2   release_date  5 non-null      object
#  3   total_tracks  5 non-null      int64
#  4   url           5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 332.0+ bytes

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                 artist_id          artist_name  \
# 0  5VVN3xZw1i2qihfITZlvCZ        G. V. Prakash
# 1  40VWCTZWMx12YUQxBZCJrR         Sujatha Dutt
# 2  1Eg5wFfEYY6DsiGelBYi4q      Krishna Tejasvi
# 3  4zCH9qm4R2DADamUHMCa6O  Anirudh Ravichander
# 4  4zCH9qm4R2DADamUHMCa6O  Anirudh Ravichander
# 5  2M4eNCvV3CJUswavkhAQg2  James Newton Howard
# 6  3oCIYpmkFw8KGWwMNPKgXh    Jennifer Lawrence
# 7  4zCH9qm4R2DADamUHMCa6O  Anirudh Ravichander
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5VVN3xZw1i2...
# 1  https://api.spotify.com/v1/artists/40VWCTZWMx1...
# 2  https://api.spotify.com/v1/artists/1Eg5wFfEYY6...
# 3  https://api.spotify.com/v1/artists/4zCH9qm4R2D...
# 4  https://api.spotify.com/v1/artists/4zCH9qm4R2D...
# 5  https://api.spotify.com/v1/artists/2M4eNCvV3CJ...
# 6  https://api.spotify.com/v1/artists/3oCIYpmkFw8...
# 7  https://api.spotify.com/v1/artists/4zCH9qm4R2D...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                   song_id                                     song_name  \
# 0  6K24Qy0Zm1JoEDtHAUSSej  Nijavaa Idoo (From "Lucky Baskhar")(Kannada)
# 1  3Vb8KkT6Ub5fFGPYJCJyLh                Rolex Theme - Background Score
# 2  209pScL6fUhISxcLWkB6rf                  Lokiverse - Background Score
# 3  416MsJxvxSKY96DCmbJIRs                              The Hanging Tree
# 4  6FQQiTpYnfc5803p84bQp1                          Vikram - Title Track
#
#    duration_ms                                                url  popularity  \
# 0       227085  https://open.spotify.com/track/6K24Qy0Zm1JoEDt...          12
# 1        53247  https://open.spotify.com/track/3Vb8KkT6Ub5fFGP...          53
# 2       156330  https://open.spotify.com/track/209pScL6fUhISxc...          57
# 3       218506  https://open.spotify.com/track/416MsJxvxSKY96D...          65
# 4       218823  https://open.spotify.com/track/6FQQiTpYnfc5803...          57
#
#              song_added                album_id               artist_id
# 0  2025-02-26T08:27:44Z  45GzIiGfnR8atWLnqnjR96  5VVN3xZw1i2qihfITZlvCZ
# 1  2025-02-26T08:28:22Z  6S5qpNyT3ZAg7m0e2XSOqx  4zCH9qm4R2DADamUHMCa6O
# 2  2025-02-26T08:28:23Z  6S5qpNyT3ZAg7m0e2XSOqx  4zCH9qm4R2DADamUHMCa6O
# 3  2025-02-26T08:33:18Z  44qAUS0siEj2plisdS25xw  2M4eNCvV3CJUswavkhAQg2
# 4  2025-02-26T08:35:10Z  0FIP7MeIO3yqL8K6uTz3b1  4zCH9qm4R2DADamUHMCa6O

# %%
song_df.head()
# Out:
#                   song_id                                     song_name  \
# 0  6K24Qy0Zm1JoEDtHAUSSej  Nijavaa Idoo (From "Lucky Baskhar")(Kannada)
# 1  3Vb8KkT6Ub5fFGPYJCJyLh                Rolex Theme - Background Score
# 2  209pScL6fUhISxcLWkB6rf                  Lokiverse - Background Score
# 3  416MsJxvxSKY96DCmbJIRs                              The Hanging Tree
# 4  6FQQiTpYnfc5803p84bQp1                          Vikram - Title Track
#
#    duration_ms                                                url  popularity  \
# 0       227085  https://open.spotify.com/track/6K24Qy0Zm1JoEDt...          12
# 1        53247  https://open.spotify.com/track/3Vb8KkT6Ub5fFGP...          53
# 2       156330  https://open.spotify.com/track/209pScL6fUhISxc...          57
# 3       218506  https://open.spotify.com/track/416MsJxvxSKY96D...          65
# 4       218823  https://open.spotify.com/track/6FQQiTpYnfc5803...          57
#
#              song_added                album_id               artist_id
# 0  2025-02-26T08:27:44Z  45GzIiGfnR8atWLnqnjR96  5VVN3xZw1i2qihfITZlvCZ
# 1  2025-02-26T08:28:22Z  6S5qpNyT3ZAg7m0e2XSOqx  4zCH9qm4R2DADamUHMCa6O
# 2  2025-02-26T08:28:23Z  6S5qpNyT3ZAg7m0e2XSOqx  4zCH9qm4R2DADamUHMCa6O
# 3  2025-02-26T08:33:18Z  44qAUS0siEj2plisdS25xw  2M4eNCvV3CJUswavkhAQg2
# 4  2025-02-26T08:35:10Z  0FIP7MeIO3yqL8K6uTz3b1  4zCH9qm4R2DADamUHMCa6O

# %%
artist_df.head()
# Out:
#                 artist_id          artist_name  \
# 0  5VVN3xZw1i2qihfITZlvCZ        G. V. Prakash
# 1  40VWCTZWMx12YUQxBZCJrR         Sujatha Dutt
# 2  1Eg5wFfEYY6DsiGelBYi4q      Krishna Tejasvi
# 3  4zCH9qm4R2DADamUHMCa6O  Anirudh Ravichander
# 5  2M4eNCvV3CJUswavkhAQg2  James Newton Howard
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5VVN3xZw1i2...
# 1  https://api.spotify.com/v1/artists/40VWCTZWMx1...
# 2  https://api.spotify.com/v1/artists/1Eg5wFfEYY6...
# 3  https://api.spotify.com/v1/artists/4zCH9qm4R2D...
# 5  https://api.spotify.com/v1/artists/2M4eNCvV3CJ...

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  45GzIiGfnR8atWLnqnjR96       Nijavaa Idoo (From "Lucky Baskhar")(Kannada)
# 1  6S5qpNyT3ZAg7m0e2XSOqx                 Vikram (Original Background Score)
# 3  44qAUS0siEj2plisdS25xw  The Hunger Games: Mockingjay Pt. 1 (Original M...
# 4  0FIP7MeIO3yqL8K6uTz3b1        Vikram (Original Motion Picture Soundtrack)
#
#   release_date  total_tracks  \
# 0   2024-11-06             1
# 1   2022-07-07            21
# 3   2014-11-21            23
# 4   2022-05-15             5
#
#                                                  url
# 0  https://open.spotify.com/album/45GzIiGfnR8atWL...
# 1  https://open.spotify.com/album/6S5qpNyT3ZAg7m0...
# 3  https://open.spotify.com/album/44qAUS0siEj2pli...
# 4  https://open.spotify.com/album/0FIP7MeIO3yqL8K...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      4 non-null      object
#  1   name          4 non-null      object
#  2   release_date  4 non-null      datetime64[ns]
#  3   total_tracks  4 non-null      int64
#  4   url           4 non-null      object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 192.0+ bytes

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.head()
# Out:
#                   song_id                                     song_name  \
# 0  6K24Qy0Zm1JoEDtHAUSSej  Nijavaa Idoo (From "Lucky Baskhar")(Kannada)
# 1  3Vb8KkT6Ub5fFGPYJCJyLh                Rolex Theme - Background Score
# 2  209pScL6fUhISxcLWkB6rf                  Lokiverse - Background Score
# 3  416MsJxvxSKY96DCmbJIRs                              The Hanging Tree
# 4  6FQQiTpYnfc5803p84bQp1                          Vikram - Title Track
#
#    duration_ms                                                url  popularity  \
# 0       227085  https://open.spotify.com/track/6K24Qy0Zm1JoEDt...          12
# 1        53247  https://open.spotify.com/track/3Vb8KkT6Ub5fFGP...          53
# 2       156330  https://open.spotify.com/track/209pScL6fUhISxc...          57
# 3       218506  https://open.spotify.com/track/416MsJxvxSKY96D...          65
# 4       218823  https://open.spotify.com/track/6FQQiTpYnfc5803...          57
#
#                  song_added                album_id               artist_id
# 0 2025-02-26 08:27:44+00:00  45GzIiGfnR8atWLnqnjR96  5VVN3xZw1i2qihfITZlvCZ
# 1 2025-02-26 08:28:22+00:00  6S5qpNyT3ZAg7m0e2XSOqx  4zCH9qm4R2DADamUHMCa6O
# 2 2025-02-26 08:28:23+00:00  6S5qpNyT3ZAg7m0e2XSOqx  4zCH9qm4R2DADamUHMCa6O
# 3 2025-02-26 08:33:18+00:00  44qAUS0siEj2plisdS25xw  2M4eNCvV3CJUswavkhAQg2
# 4 2025-02-26 08:35:10+00:00  0FIP7MeIO3yqL8K6uTz3b1  4zCH9qm4R2DADamUHMCa6O

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      5 non-null      object
#  1   song_name    5 non-null      object
#  2   duration_ms  5 non-null      int64
#  3   url          5 non-null      object
#  4   popularity   5 non-null      int64
#  5   song_added   5 non-null      datetime64[ns, UTC]
#  6   album_id     5 non-null      object
#  7   artist_id    5 non-null      object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 452.0+ bytes
